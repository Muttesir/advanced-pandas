# %%
import pandas as pd
df=pd.read_csv('listings.csv')
df.head()
# Out:
#      id                                               name  host_id  \
# 0  2318  Casa Madrona - Urban Oasis 1 block from the park!     2536
# 1  6606                Fab, private seattle urban cottage!    14942
# 2  9419                Glorious sun room w/ memory foambed    30559
# 3  9531                The Adorable Sweet Orange Craftsman    31481
# 4  9534                   The Coolest Tangerine Dream MIL!    31481
#
#    host_name  neighbourhood_group   neighbourhood  latitude  longitude  \
# 0      Megan         Central Area         Madrona  47.61094 -122.29286
# 1      Joyce  Other neighborhoods     Wallingford  47.65444 -122.33629
# 2  Angielena  Other neighborhoods      Georgetown  47.55017 -122.31937
# 3     Cassie         West Seattle  Fairmount Park  47.55495 -122.38663
# 4     Cassie         West Seattle  Fairmount Park  47.55627 -122.38607
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df.tail()
# Out:
#             id                                               name    host_id  \
# 4091  50998875  Authentic Brick Condo - Great Wifi & little ex...  383863361
# 4092  51010345  Bright First Hill 1BR w/ Gym, Lounge, Roof, 90...  107434423
# 4093  51023498          Well-kept apartment home | 2BR in Seattle  359069961
# 4094  51023636  Cozy Crash Pad! (Yard, Parking, DT Access via ...   68726541
# 4095  51033528             Great Apartment home | 2 BR in Seattle  368944610
#
#        host_name  neighbourhood_group        neighbourhood   latitude  \
# 4091       Brady             Downtown           First Hill  47.608750
# 4092  Blueground         Central Area                Minor  47.608200
# 4093         Kia              Cascade     South Lake Union  47.623880
# 4094      Barron          Beacon Hill      Mid-Beacon Hill  47.549706
# 4095     Carolyn  University District  University District  47.660532
#
#        longitude        room_type  price  minimum_nights  number_of_reviews  \
# ...

# %%
df.drop(['name','host_id'],axis=1, inplace=True)

# %%
df.head()
# Out:
#      id  host_name  neighbourhood_group   neighbourhood  latitude  longitude  \
# 0  2318      Megan         Central Area         Madrona  47.61094 -122.29286
# 1  6606      Joyce  Other neighborhoods     Wallingford  47.65444 -122.33629
# 2  9419  Angielena  Other neighborhoods      Georgetown  47.55017 -122.31937
# 3  9531     Cassie         West Seattle  Fairmount Park  47.55495 -122.38663
# 4  9534     Cassie         West Seattle  Fairmount Park  47.55627 -122.38607
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0  Entire home/apt    475              30                 32  2020-02-01
# 1  Entire home/apt    102               2                153  2021-07-12
# 2     Private room     75               2                149  2021-06-28
# 3  Entire home/apt    165               5                 45  2021-05-31
# 4  Entire home/apt    125               5                 58  2021-04-25
#
# ...

# %%
df1=df.set_index('id', drop=True, append=False, inplace=False, verify_integrity=False)

# %%
df1[0:3]
# Out:
#       host_name  neighbourhood_group neighbourhood  latitude  longitude  \
# id
# 2318      Megan         Central Area       Madrona  47.61094 -122.29286
# 6606      Joyce  Other neighborhoods   Wallingford  47.65444 -122.33629
# 9419  Angielena  Other neighborhoods    Georgetown  47.55017 -122.31937
#
#             room_type  price  minimum_nights  number_of_reviews last_review  \
# id
# 2318  Entire home/apt    475              30                 32  2020-02-01
# 6606  Entire home/apt    102               2                153  2021-07-12
# 9419     Private room     75               2                149  2021-06-28
#
#       reviews_per_month  calculated_host_listings_count  availability_365
# id
# 2318               0.58                               2               238
# 6606               2.45                               1                87
# 9419               1.12                               9               275

# %%
df2=df1.rename(columns={'last_review':'Date_Of_Review'}, inplace=False)
df2.head()
# Out:
#       host_name  neighbourhood_group   neighbourhood  latitude  longitude  \
# id
# 2318      Megan         Central Area         Madrona  47.61094 -122.29286
# 6606      Joyce  Other neighborhoods     Wallingford  47.65444 -122.33629
# 9419  Angielena  Other neighborhoods      Georgetown  47.55017 -122.31937
# 9531     Cassie         West Seattle  Fairmount Park  47.55495 -122.38663
# 9534     Cassie         West Seattle  Fairmount Park  47.55627 -122.38607
#
#             room_type  price  minimum_nights  number_of_reviews  \
# id
# 2318  Entire home/apt    475              30                 32
# 6606  Entire home/apt    102               2                153
# 9419     Private room     75               2                149
# 9531  Entire home/apt    165               5                 45
# 9534  Entire home/apt    125               5                 58
#
#      Date_Of_Review  reviews_per_month  calculated_host_listings_count  \
# id
# ...
